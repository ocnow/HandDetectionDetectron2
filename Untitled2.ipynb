# %%
import torch, torchvision
import torch
assert torch.__version__.startswith("1.7")

# %%
# Some basic setup:
# Setup detectron2 logger
import detectron2
from detectron2.utils.logger import setup_logger
setup_logger()

# import some common libraries
import numpy as np
import os, json, cv2, random
from google.colab.patches import cv2_imshow

# import some common detectron2 utilities
from detectron2 import model_zoo
from detectron2.engine import DefaultPredictor
from detectron2.config import get_cfg
from detectron2.utils.visualizer import Visualizer
from detectron2.data import MetadataCatalog, DatasetCatalog

import pandas as pd
import scipy.io as sio

# %%
# !wget http://vision.soic.indiana.edu/egohands_files/egohands_data.zip
# !unzip egohands_data.zip > /dev/null
# Out:
# --2021-01-26 18:38:09--  http://vision.soic.indiana.edu/egohands_files/egohands_data.zip
# Resolving vision.soic.indiana.edu (vision.soic.indiana.edu)... 156.56.83.21
# Connecting to vision.soic.indiana.edu (vision.soic.indiana.edu)|156.56.83.21|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1332784625 (1.2G) [application/zip]
# Saving to: ‘egohands_data.zip’
#
# egohands_data.zip   100%[===================>]   1.24G  30.9MB/s    in 48s
#
# 2021-01-26 18:38:56 (26.7 MB/s) - ‘egohands_data.zip’ saved [1332784625/1332784625]

# %%
BASE_PATH = '_LABELLED_SAMPLES/'

# %%
folders = os.listdir('_LABELLED_SAMPLES')

# %%
folder_names = []
image_names = []
polygons_master = []

# %%
for folder in folders:
  img_names = [x for x in os.listdir(BASE_PATH + folder) if x.split('.')[-1] == 'jpg']
  poly_file = sio.loadmat(BASE_PATH + folder +'/'+ 'polygons.mat')['polygons'][0]
  i = 0
  for img_name in img_names:
    folder_names.append(folder)
    image_names.append(img_name)
    polygons_master.append(poly_file[i])
    i = i + 1

# %%
len(polygons_master)
# Out:
# 4800

# %%
df = pd.DataFrame({'folder_name':folder_names,'image_names':image_names,'polygons':polygons_master})

# %%
from sklearn.model_selection import train_test_split

# %%
train,test = train_test_split(df,test_size=0.2)

# %%
from detectron2.structures import BoxMode

# %%
hands = train.loc[0]

# %%
filename = os.path.join(BASE_PATH + hands['folder_name'],hands['image_names'])

# %%
filename
# Out:
# '_LABELLED_SAMPLES/CARDS_OFFICE_T_H/frame_2496.jpg'

# %%
cv2.imread(filename).shape[:2]
# Out:
# (720, 1280)

# %%
def get_balloon_dicts(img_dir):
  df = None
  if img_dir == 'train':
    df = train
  else:
    df = test
  
  dataset_dicts = []
  i = 0
  for index, row in df.iterrows():
    i = i + 1
    print("doing for index "+str(i))
    record = {}

    filename = os.path.join(BASE_PATH + row['folder_name'], row['image_names'])
    #height, width = cv2.imread(filename).shape[:2]

    record["file_name"] = filename
    record["image_id"] = row['image_names'].split('.')[0]
    record["height"] = 720
    record["width"] = 1280

    annos = row['polygons']
    objs = []
    
    for hand in annos:
      x_min = 2000
      y_min = 2000
      x_max = -1
      y_max = -1

      #array to hold x and y values of hand pixels
      poly = []

      if hand.size > 0:
        for pixel in hand:
          x = int(pixel[0])
          y = int(pixel[1])
          
          poly.append(x)
          poly.append(y)
          
          if  x > x_max:
              x_max = x
          if x < x_min:
              x_min = x
          if y > y_max:
              y_max = y
          if y < y_max:
              y_min = y
          
          #array to corners of bbox
          corners = [x_min,y_min,x_max,y_max]

          obj = {
                "bbox": corners,
                "bbox_mode": BoxMode.XYXY_ABS,
                "segmentation": [poly],
                "category_id": 0,
            }
          objs.append(obj)
    record["annotations"] = objs
    dataset_dicts.append(record)
  return dataset_dicts

# %%
dict = get_balloon_dicts('train')
# Out:
# doing for index 1
# doing for index 2
# doing for index 3
# doing for index 4
# doing for index 5
# doing for index 6
# doing for index 7
# doing for index 8
# doing for index 9
# doing for index 10
# doing for index 11
# doing for index 12
# doing for index 13
# doing for index 14
# doing for index 15
# doing for index 16
# doing for index 17
# doing for index 18
# doing for index 19
# doing for index 20
# doing for index 21
# doing for index 22
# doing for index 23
# doing for index 24
# doing for index 25
# doing for index 26
# doing for index 27
# doing for index 28
# doing for index 29
# doing for index 30
# doing for index 31
# doing for index 32
# doing for index 33
# doing for index 34
# doing for index 35
# doing for index 36
# doing for index 37
# doing for index 38
# doing for index 39
# doing for index 40
# doing for index 41
# doing for index 42
# doing for index 43
# doing for index 44
# doing for index 45
# doing for index 46
# doing for index 47
# doing for index 48
# doing for index 49
# doing for index 50
# doing for index 51
# doing for index 52
# doing for index 53
# doing for index 54
# doing for index 55
# doing for index 56
# doing for index 57
# doing for index 58
# doing for index 59
# doing for index 60
# doing for index 61
# doing for index 62
# doing for index 63
# doing for index 64
# doing for index 65
# doing for index 66
# doing for index 67
# doing for index 68
# doing for index 69
# doing for index 70
# doing for index 71
# doing for index 72
# doing for index 73
# doing for index 74
# doing for index 75
# doing for index 76
# doing for index 77
# doing for index 78
# doing for index 79
# doing for index 80
# doing for index 81
# doing for index 82
# doing for index 83
# doing for index 84
# doing for index 85
# doing for index 86
# doing for index 87
# doing for index 88
# doing for index 89
# doing for index 90
# doing for index 91
# doing for index 92
# doing for index 93
# doing for index 94
# doing for index 95
# doing for index 96
# doing for index 97
# doing for index 98
# doing for index 99
# doing for index 100
# doing for index 101
# doing for index 102
# doing for index 103
# doing for index 104
# doing for index 105
# doing for index 106
# doing for index 107
# doing for index 108
# doing for index 109
# doing for index 110
# doing for index 111
# doing for index 112
# doing for index 113
# doing for index 114
# doing for index 115
# doing for index 116
# doing for index 117
# doing for index 118
# doing for index 119
# doing for index 120
# doing for index 121
# doing for index 122
# doing for index 123
# doing for index 124
# doing for index 125
# doing for index 126
# doing for index 127
# doing for index 128
# doing for index 129
# doing for index 130
# doing for index 131
# doing for index 132
# doing for index 133
# doing for index 134
# doing for index 135
# doing for index 136
# doing for index 137
# doing for index 138
# doing for index 139
# doing for index 140
# doing for index 141
# doing for index 142
# doing for index 143
# doing for index 144
# doing for index 145
# doing for index 146
# doing for index 147
# doing for index 148
# doing for index 149
# doing for index 150
# doing for index 151
# doing for index 152
# doing for index 153
# doing for index 154
# doing for index 155
# doing for index 156
# doing for index 157
# doing for index 158
# doing for index 159
# doing for index 160
# doing for index 161
# doing for index 162
# doing for index 163
# doing for index 164
# doing for index 165
# doing for index 166
# doing for index 167
# doing for index 168
# doing for index 169
# doing for index 170
# doing for index 171
# doing for index 172
# doing for index 173
# doing for index 174
# doing for index 175
# doing for index 176
# doing for index 177
# doing for index 178
# doing for index 179
# doing for index 180
# doing for index 181
# doing for index 182
# doing for index 183
# doing for index 184
# doing for index 185
# doing for index 186
# doing for index 187
# doing for index 188
# doing for index 189
# doing for index 190
# doing for index 191
# doing for index 192
# doing for index 193
# doing for index 194
# doing for index 195
# doing for index 196
# doing for index 197
# doing for index 198
# doing for index 199
# doing for index 200
# doing for index 201
# doing for index 202
# doing for index 203
# doing for index 204
# doing for index 205
# doing for index 206
# doing for index 207
# doing for index 208
# doing for index 209
# doing for index 210
# doing for index 211
# doing for index 212
# doing for index 213
# doing for index 214
# doing for index 215
# doing for index 216
# doing for index 217
# doing for index 218
# doing for index 219
# doing for index 220
# doing for index 221
# doing for index 222
# doing for index 223
# doing for index 224
# doing for index 225
# doing for index 226
# doing for index 227
# doing for index 228
# doing for index 229
# doing for index 230
# doing for index 231
# doing for index 232
# doing for index 233
# doing for index 234
# doing for index 235
# doing for index 236
# doing for index 237
# doing for index 238
# doing for index 239
# doing for index 240
# doing for index 241
# doing for index 242
# doing for index 243
# doing for index 244
# doing for index 245
# doing for index 246
# doing for index 247
# doing for index 248
# doing for index 249
# doing for index 250
# doing for index 251
# doing for index 252
# doing for index 253
# doing for index 254
# doing for index 255
# doing for index 256
# doing for index 257
# doing for index 258
# doing for index 259
# doing for index 260
# doing for index 261
# doing for index 262
# doing for index 263
# doing for index 264
# doing for index 265
# doing for index 266
# doing for index 267
# doing for index 268
# doing for index 269
# doing for index 270
# doing for index 271
# doing for index 272
# doing for index 273
# doing for index 274
# doing for index 275
# doing for index 276
# doing for index 277
# doing for index 278
# doing for index 279
# doing for index 280
# doing for index 281
# doing for index 282
# doing for index 283
# doing for index 284
# doing for index 285
# doing for index 286
# doing for index 287
# doing for index 288
# doing for index 289
# doing for index 290
# doing for index 291
# doing for index 292
# doing for index 293
# doing for index 294
# doing for index 295
# doing for index 296
# doing for index 297
# doing for index 298
# doing for index 299
# doing for index 300
# doing for index 301
# doing for index 302
# doing for index 303
# doing for index 304
# doing for index 305
# doing for index 306
# doing for index 307
# doing for index 308
# doing for index 309
# doing for index 310
# doing for index 311
# doing for index 312
# doing for index 313
# doing for index 314
# doing for index 315
# doing for index 316
# doing for index 317
# doing for index 318
# doing for index 319
# doing for index 320
# doing for index 321
# doing for index 322
# doing for index 323
# doing for index 324
# doing for index 325
# doing for index 326
# doing for index 327
# doing for index 328
# doing for index 329
# doing for index 330
# doing for index 331
# doing for index 332
# doing for index 333
# doing for index 334
# doing for index 335
# doing for index 336
# doing for index 337
# doing for index 338
# doing for index 339
# doing for index 340
# doing for index 341
# doing for index 342
# doing for index 343
# doing for index 344
# doing for index 345
# doing for index 346
# doing for index 347
# doing for index 348
# doing for index 349
# doing for index 350
# doing for index 351
# doing for index 352
# doing for index 353
# doing for index 354
# doing for index 355
# doing for index 356
# doing for index 357
# doing for index 358
# doing for index 359
# doing for index 360
# doing for index 361
# doing for index 362
# doing for index 363
# doing for index 364
# doing for index 365
# doing for index 366
# doing for index 367
# doing for index 368
# doing for index 369
# doing for index 370
# doing for index 371
# doing for index 372
# doing for index 373
# doing for index 374
# doing for index 375
# doing for index 376
# doing for index 377
# doing for index 378
# doing for index 379
# doing for index 380
# doing for index 381
# doing for index 382
# doing for index 383
# doing for index 384
# doing for index 385
# doing for index 386
# doing for index 387
# doing for index 388
# doing for index 389
# doing for index 390
# doing for index 391
# doing for index 392
# doing for index 393
# doing for index 394
# doing for index 395
# doing for index 396
# doing for index 397
# doing for index 398
# doing for index 399
# doing for index 400
# doing for index 401
# doing for index 402
# doing for index 403
# doing for index 404
# doing for index 405
# doing for index 406
# doing for index 407
# doing for index 408
# doing for index 409
# doing for index 410
# doing for index 411
# doing for index 412
# doing for index 413
# doing for index 414
# doing for index 415
# doing for index 416
# doing for index 417
# doing for index 418
# doing for index 419
# doing for index 420
# doing for index 421
# doing for index 422
# doing for index 423
# doing for index 424
# doing for index 425
# doing for index 426
# doing for index 427
# doing for index 428
# doing for index 429
# doing for index 430
# doing for index 431
# doing for index 432
# doing for index 433
# doing for index 434
# doing for index 435
# doing for index 436
# doing for index 437
# doing for index 438
# doing for index 439
# doing for index 440
# doing for index 441
# doing for index 442
# doing for index 443
# doing for index 444
# doing for index 445
# doing for index 446
# doing for index 447
# doing for index 448
# doing for index 449
# doing for index 450
# doing for index 451
# doing for index 452
# doing for index 453
# doing for index 454
# doing for index 455
# doing for index 456
# doing for index 457
# doing for index 458
# doing for index 459
# doing for index 460
# doing for index 461
# doing for index 462
# doing for index 463
# doing for index 464
# doing for index 465
# doing for index 466
# doing for index 467
# doing for index 468
# doing for index 469
# doing for index 470
# doing for index 471
# doing for index 472
# doing for index 473
# doing for index 474
# doing for index 475
# doing for index 476
# doing for index 477
# doing for index 478
# doing for index 479
# doing for index 480
# doing for index 481
# doing for index 482
# doing for index 483
# doing for index 484
# doing for index 485
# doing for index 486
# doing for index 487
# doing for index 488
# doing for index 489
# doing for index 490
# doing for index 491
# doing for index 492
# doing for index 493
# doing for index 494
# doing for index 495
# doing for index 496
# doing for index 497
# doing for index 498
# doing for index 499
# doing for index 500
# doing for index 501
# doing for index 502
# doing for index 503
# doing for index 504
# doing for index 505
# doing for index 506
# doing for index 507
# doing for index 508
# doing for index 509
# doing for index 510
# doing for index 511
# doing for index 512
# doing for index 513
# doing for index 514
# doing for index 515
# doing for index 516
# doing for index 517
# doing for index 518
# doing for index 519
# doing for index 520
# doing for index 521
# doing for index 522
# doing for index 523
# doing for index 524
# doing for index 525
# doing for index 526
# doing for index 527
# doing for index 528
# doing for index 529
# doing for index 530
# doing for index 531
# doing for index 532
# doing for index 533
# doing for index 534
# doing for index 535
# doing for index 536
# doing for index 537
# doing for index 538
# doing for index 539
# doing for index 540
# doing for index 541
# doing for index 542
# doing for index 543
# doing for index 544
# doing for index 545
# doing for index 546
# doing for index 547
# doing for index 548
# doing for index 549
# doing for index 550
# doing for index 551
# doing for index 552
# doing for index 553
# doing for index 554
# doing for index 555
# doing for index 556
# doing for index 557
# doing for index 558
# doing for index 559
# doing for index 560
# doing for index 561
# doing for index 562
# doing for index 563
# doing for index 564
# doing for index 565
# doing for index 566
# doing for index 567
# doing for index 568
# doing for index 569
# doing for index 570
# doing for index 571
# doing for index 572
# doing for index 573
# doing for index 574
# doing for index 575
# doing for index 576
# doing for index 577
# doing for index 578
# doing for index 579
# doing for index 580
# doing for index 581
# doing for index 582
# doing for index 583
# doing for index 584
# doing for index 585
# doing for index 586
# doing for index 587
# doing for index 588
# doing for index 589
# doing for index 590
# doing for index 591
# doing for index 592
# doing for index 593
# doing for index 594
# doing for index 595
# doing for index 596
# doing for index 597
# doing for index 598
# doing for index 599
# doing for index 600
# doing for index 601
# doing for index 602
# doing for index 603
# doing for index 604
# doing for index 605
# doing for index 606
# doing for index 607
# doing for index 608
# doing for index 609
# doing for index 610
# doing for index 611
# doing for index 612
# doing for index 613
# doing for index 614
# doing for index 615
# doing for index 616
# doing for index 617
# doing for index 618
# doing for index 619
# doing for index 620
# doing for index 621
# doing for index 622
# doing for index 623
# doing for index 624
# doing for index 625
# doing for index 626
# doing for index 627
# doing for index 628
# doing for index 629
# doing for index 630
# doing for index 631
# doing for index 632
# doing for index 633
# doing for index 634
# doing for index 635
# doing for index 636
# doing for index 637
# doing for index 638
# doing for index 639
# doing for index 640
# doing for index 641
# doing for index 642
# doing for index 643
# doing for index 644
# doing for index 645
# doing for index 646
# doing for index 647
# doing for index 648
# doing for index 649
# doing for index 650
# doing for index 651
# doing for index 652
# doing for index 653
# doing for index 654
# doing for index 655
# doing for index 656
# doing for index 657
# doing for index 658
# doing for index 659
# doing for index 660
# doing for index 661
# doing for index 662
# doing for index 663
# doing for index 664
# doing for index 665
# doing for index 666
# doing for index 667
# doing for index 668
# doing for index 669
# doing for index 670
# doing for index 671
# doing for index 672
# doing for index 673
# doing for index 674
# doing for index 675
# doing for index 676
# doing for index 677
# doing for index 678
# doing for index 679
# doing for index 680
# doing for index 681
# doing for index 682
# doing for index 683
# doing for index 684
# doing for index 685
# doing for index 686
# doing for index 687
# doing for index 688
# doing for index 689
# doing for index 690
# doing for index 691
# doing for index 692
# doing for index 693
# doing for index 694
# doing for index 695
# doing for index 696
# doing for index 697
# doing for index 698
# doing for index 699
# doing for index 700
# doing for index 701
# doing for index 702
# doing for index 703
# doing for index 704
# doing for index 705
# doing for index 706
# doing for index 707
# doing for index 708
# doing for index 709
# doing for index 710
# doing for index 711
# doing for index 712
# doing for index 713
# doing for index 714
# doing for index 715
# doing for index 716
# doing for index 717
# doing for index 718
# doing for index 719
# doing for index 720
# doing for index 721
# doing for index 722
# doing for index 723
# doing for index 724
# doing for index 725
# doing for index 726
# doing for index 727
# doing for index 728
# doing for index 729
# doing for index 730
# doing for index 731
# doing for index 732
# doing for index 733
# doing for index 734
# doing for index 735
# doing for index 736
# doing for index 737
# doing for index 738
# doing for index 739
# doing for index 740
# doing for index 741
# doing for index 742
# doing for index 743
# doing for index 744
# doing for index 745
# doing for index 746
# doing for index 747
# doing for index 748
# doing for index 749
# doing for index 750
# doing for index 751
# doing for index 752
# doing for index 753
# doing for index 754
# doing for index 755
# doing for index 756
# doing for index 757
# doing for index 758
# doing for index 759
# doing for index 760
# doing for index 761
# doing for index 762
# doing for index 763
# doing for index 764
# doing for index 765
# doing for index 766
# doing for index 767
# doing for index 768
# doing for index 769
# doing for index 770
# doing for index 771
# doing for index 772
# doing for index 773
# doing for index 774
# doing for index 775
# doing for index 776
# doing for index 777
# doing for index 778
# doing for index 779
# doing for index 780
# doing for index 781
# doing for index 782
# doing for index 783
# doing for index 784
# doing for index 785
# doing for index 786
# doing for index 787
# doing for index 788
# doing for index 789
# doing for index 790
# doing for index 791
# doing for index 792
# doing for index 793
# doing for index 794
# doing for index 795
# doing for index 796
# doing for index 797
# doing for index 798
# doing for index 799
# doing for index 800
# doing for index 801
# doing for index 802
# doing for index 803
# doing for index 804
# doing for index 805
# doing for index 806
# doing for index 807
# doing for index 808
# doing for index 809
# doing for index 810
# doing for index 811
# doing for index 812
# doing for index 813
# doing for index 814
# doing for index 815
# doing for index 816
# doing for index 817
# doing for index 818
# doing for index 819
# doing for index 820
# doing for index 821
# doing for index 822
# doing for index 823
# doing for index 824
# doing for index 825
# doing for index 826
# doing for index 827
# doing for index 828
# doing for index 829
# doing for index 830
# doing for index 831
# doing for index 832
# doing for index 833
# doing for index 834
# doing for index 835
# doing for index 836
# doing for index 837
# doing for index 838
# doing for index 839
# doing for index 840
# doing for index 841
# doing for index 842
# doing for index 843
# doing for index 844
# doing for index 845
# doing for index 846
# doing for index 847
# doing for index 848
# doing for index 849
# doing for index 850
# doing for index 851
# doing for index 852
# doing for index 853
# doing for index 854
# doing for index 855
# doing for index 856
# doing for index 857
# doing for index 858
# doing for index 859
# doing for index 860
# doing for index 861
# doing for index 862
# doing for index 863
# doing for index 864
# doing for index 865
# doing for index 866
# doing for index 867
# doing for index 868
# doing for index 869
# doing for index 870
# doing for index 871
# doing for index 872
# doing for index 873
# doing for index 874
# doing for index 875
# doing for index 876
# doing for index 877
# doing for index 878
# doing for index 879
# doing for index 880
# doing for index 881
# doing for index 882
# doing for index 883
# doing for index 884
# doing for index 885
# doing for index 886
# doing for index 887
# doing for index 888
# doing for index 889
# doing for index 890
# doing for index 891
# doing for index 892
# doing for index 893
# doing for index 894
# doing for index 895
# doing for index 896
# doing for index 897
# doing for index 898
# doing for index 899
# doing for index 900
# doing for index 901
# doing for index 902
# doing for index 903
# doing for index 904
# doing for index 905
# doing for index 906
# doing for index 907
# doing for index 908
# doing for index 909
# doing for index 910
# doing for index 911
# doing for index 912
# doing for index 913
# doing for index 914
# doing for index 915
# doing for index 916
# doing for index 917
# doing for index 918
# doing for index 919
# doing for index 920
# doing for index 921
# doing for index 922
# doing for index 923
# doing for index 924
# doing for index 925
# doing for index 926
# doing for index 927
# doing for index 928
# doing for index 929
# doing for index 930
# doing for index 931
# doing for index 932
# doing for index 933
# doing for index 934
# doing for index 935
# doing for index 936
# doing for index 937
# doing for index 938
# doing for index 939
# doing for index 940
# doing for index 941
# doing for index 942
# doing for index 943
# doing for index 944
# doing for index 945
# doing for index 946
# doing for index 947
# doing for index 948
# doing for index 949
# doing for index 950
# doing for index 951
# doing for index 952
# doing for index 953
# doing for index 954
# doing for index 955
# doing for index 956
# doing for index 957
# doing for index 958
# doing for index 959
# doing for index 960
# doing for index 961
# doing for index 962
# doing for index 963
# doing for index 964
# doing for index 965
# doing for index 966
# doing for index 967
# doing for index 968
# doing for index 969
# doing for index 970
# doing for index 971
# doing for index 972
# doing for index 973
# doing for index 974
# doing for index 975
# doing for index 976
# doing for index 977
# doing for index 978
# doing for index 979
# doing for index 980
# doing for index 981
# doing for index 982
# doing for index 983
# doing for index 984
# doing for index 985
# doing for index 986
# doing for index 987
# doing for index 988
# doing for index 989
# doing for index 990
# doing for index 991
# doing for index 992
# doing for index 993
# doing for index 994
# doing for index 995
# doing for index 996
# doing for index 997
# doing for index 998
# doing for index 999
# doing for index 1000
# doing for index 1001
# doing for index 1002
# doing for index 1003
# doing for index 1004
# doing for index 1005
# doing for index 1006
# doing for index 1007
# doing for index 1008
# doing for index 1009
# doing for index 1010
# doing for index 1011
# doing for index 1012
# doing for index 1013
# doing for index 1014
# doing for index 1015
# doing for index 1016
# doing for index 1017
# doing for index 1018
# doing for index 1019
# doing for index 1020
# doing for index 1021
# doing for index 1022
# doing for index 1023
# doing for index 1024
# doing for index 1025
# doing for index 1026
# doing for index 1027
# doing for index 1028
# doing for index 1029
# doing for index 1030
# doing for index 1031
# doing for index 1032
# doing for index 1033
# doing for index 1034
# doing for index 1035
# doing for index 1036
# doing for index 1037
# doing for index 1038
# doing for index 1039
# doing for index 1040
# doing for index 1041
# doing for index 1042
# doing for index 1043
# doing for index 1044
# doing for index 1045
# doing for index 1046
# doing for index 1047
# doing for index 1048
# doing for index 1049
# doing for index 1050
# doing for index 1051
# doing for index 1052
# doing for index 1053
# doing for index 1054
# doing for index 1055
# doing for index 1056
# doing for index 1057
# doing for index 1058
# doing for index 1059
# doing for index 1060
# doing for index 1061
# doing for index 1062
# doing for index 1063
# doing for index 1064
# doing for index 1065
# doing for index 1066
# doing for index 1067
# doing for index 1068
# doing for index 1069
# doing for index 1070
# doing for index 1071
# doing for index 1072
# doing for index 1073
# doing for index 1074
# doing for index 1075
# doing for index 1076
# doing for index 1077
# doing for index 1078
# doing for index 1079
# doing for index 1080
# doing for index 1081
# doing for index 1082
# doing for index 1083
# doing for index 1084
# doing for index 1085
# doing for index 1086
# doing for index 1087
# doing for index 1088
# doing for index 1089
# doing for index 1090
# doing for index 1091
# doing for index 1092
# doing for index 1093
# doing for index 1094
# doing for index 1095
# doing for index 1096
# doing for index 1097
# doing for index 1098
# doing for index 1099
# doing for index 1100
# doing for index 1101
# doing for index 1102
# doing for index 1103
# doing for index 1104
# doing for index 1105
# doing for index 1106
# doing for index 1107
# doing for index 1108
# doing for index 1109
# doing for index 1110
# doing for index 1111
# doing for index 1112
# doing for index 1113
# doing for index 1114
# doing for index 1115
# doing for index 1116
# doing for index 1117
# doing for index 1118
# doing for index 1119
# doing for index 1120
# doing for index 1121
# doing for index 1122
# doing for index 1123
# doing for index 1124
# doing for index 1125
# doing for index 1126
# doing for index 1127
# doing for index 1128
# doing for index 1129
# doing for index 1130
# doing for index 1131
# doing for index 1132
# doing for index 1133
# doing for index 1134
# doing for index 1135
# doing for index 1136
# doing for index 1137
# doing for index 1138
# doing for index 1139
# doing for index 1140
# doing for index 1141
# doing for index 1142
# doing for index 1143
# doing for index 1144
# doing for index 1145
# doing for index 1146
# doing for index 1147
# doing for index 1148
# doing for index 1149
# doing for index 1150
# doing for index 1151
# doing for index 1152
# doing for index 1153
# doing for index 1154
# doing for index 1155
# doing for index 1156
# doing for index 1157
# doing for index 1158
# doing for index 1159
# doing for index 1160
# doing for index 1161
# doing for index 1162
# doing for index 1163
# doing for index 1164
# doing for index 1165
# doing for index 1166
# doing for index 1167
# doing for index 1168
# doing for index 1169
# doing for index 1170
# doing for index 1171
# doing for index 1172
# doing for index 1173
# doing for index 1174
# doing for index 1175
# doing for index 1176
# doing for index 1177
# doing for index 1178
# doing for index 1179
# doing for index 1180
# doing for index 1181
# doing for index 1182
# doing for index 1183
# doing for index 1184
# doing for index 1185
# doing for index 1186
# doing for index 1187
# doing for index 1188
# doing for index 1189
# doing for index 1190
# doing for index 1191
# doing for index 1192
# doing for index 1193
# doing for index 1194
# doing for index 1195
# doing for index 1196
# doing for index 1197
# doing for index 1198
# doing for index 1199
# doing for index 1200
# doing for index 1201
# doing for index 1202
# doing for index 1203
# doing for index 1204
# doing for index 1205
# doing for index 1206
# doing for index 1207
# doing for index 1208
# doing for index 1209
# doing for index 1210
# doing for index 1211
# doing for index 1212
# doing for index 1213
# doing for index 1214
# doing for index 1215
# doing for index 1216
# doing for index 1217
# doing for index 1218
# doing for index 1219
# doing for index 1220
# doing for index 1221
# doing for index 1222
# doing for index 1223
# doing for index 1224
# doing for index 1225
# doing for index 1226
# doing for index 1227
# doing for index 1228
# doing for index 1229
# doing for index 1230
# doing for index 1231
# doing for index 1232
# doing for index 1233
# doing for index 1234
# doing for index 1235
# doing for index 1236
# doing for index 1237
# doing for index 1238
# doing for index 1239
# doing for index 1240
# doing for index 1241
# doing for index 1242
# doing for index 1243
# doing for index 1244
# doing for index 1245
# doing for index 1246
# doing for index 1247
# doing for index 1248
# doing for index 1249
# doing for index 1250
# doing for index 1251
# doing for index 1252
# doing for index 1253
# doing for index 1254
# doing for index 1255
# doing for index 1256
# doing for index 1257
# doing for index 1258
# doing for index 1259
# doing for index 1260
# doing for index 1261
# doing for index 1262
# doing for index 1263
# doing for index 1264
# doing for index 1265
# doing for index 1266
# doing for index 1267
# doing for index 1268
# doing for index 1269
# doing for index 1270
# doing for index 1271
# doing for index 1272
# doing for index 1273
# doing for index 1274
# doing for index 1275
# doing for index 1276
# doing for index 1277
# doing for index 1278
# doing for index 1279
# doing for index 1280
# doing for index 1281
# doing for index 1282
# doing for index 1283
# doing for index 1284
# doing for index 1285
# doing for index 1286
# doing for index 1287
# doing for index 1288
# doing for index 1289
# doing for index 1290
# doing for index 1291
# doing for index 1292
# doing for index 1293
# doing for index 1294
# doing for index 1295
# doing for index 1296
# doing for index 1297
# doing for index 1298
# doing for index 1299
# doing for index 1300
# doing for index 1301
# doing for index 1302
# doing for index 1303
# doing for index 1304
# doing for index 1305
# doing for index 1306
# doing for index 1307
# doing for index 1308
# doing for index 1309
# doing for index 1310
# doing for index 1311
# doing for index 1312
# doing for index 1313
# doing for index 1314
# doing for index 1315
# doing for index 1316
# doing for index 1317
# doing for index 1318
# doing for index 1319
# doing for index 1320
# doing for index 1321
# doing for index 1322
# doing for index 1323
# doing for index 1324
# doing for index 1325
# doing for index 1326
# doing for index 1327
# doing for index 1328
# doing for index 1329
# doing for index 1330
# doing for index 1331
# doing for index 1332
# doing for index 1333
# doing for index 1334
# doing for index 1335
# doing for index 1336
# doing for index 1337
# doing for index 1338
# doing for index 1339
# doing for index 1340
# doing for index 1341
# doing for index 1342
# doing for index 1343
# doing for index 1344
# doing for index 1345
# doing for index 1346
# doing for index 1347
# doing for index 1348
# doing for index 1349
# doing for index 1350
# doing for index 1351
# doing for index 1352
# doing for index 1353
# doing for index 1354
# doing for index 1355
# doing for index 1356
# doing for index 1357
# doing for index 1358
# doing for index 1359
# doing for index 1360
# doing for index 1361
# doing for index 1362
# doing for index 1363
# doing for index 1364
# doing for index 1365
# doing for index 1366
# doing for index 1367
# doing for index 1368
# doing for index 1369
# doing for index 1370
# doing for index 1371
# doing for index 1372
# doing for index 1373
# doing for index 1374
# doing for index 1375
# doing for index 1376
# doing for index 1377
# doing for index 1378
# doing for index 1379
# doing for index 1380
# doing for index 1381
# doing for index 1382
# doing for index 1383
# doing for index 1384
# doing for index 1385
# doing for index 1386
# doing for index 1387
# doing for index 1388
# doing for index 1389
# doing for index 1390
# doing for index 1391
# doing for index 1392
# doing for index 1393
# doing for index 1394
# doing for index 1395
# doing for index 1396
# doing for index 1397
# doing for index 1398
# doing for index 1399
# doing for index 1400
# doing for index 1401
# doing for index 1402
# doing for index 1403
# doing for index 1404
# doing for index 1405
# doing for index 1406
# doing for index 1407
# doing for index 1408
# doing for index 1409
# doing for index 1410
# doing for index 1411
# doing for index 1412
# doing for index 1413
# doing for index 1414
# doing for index 1415
# doing for index 1416
# doing for index 1417
# doing for index 1418
# doing for index 1419
# doing for index 1420
# doing for index 1421
# doing for index 1422
# doing for index 1423
# doing for index 1424
# doing for index 1425
# doing for index 1426
# doing for index 1427
# doing for index 1428
# doing for index 1429
# doing for index 1430
# doing for index 1431
# doing for index 1432
# doing for index 1433
# doing for index 1434
# doing for index 1435
# doing for index 1436
# doing for index 1437
# doing for index 1438
# doing for index 1439
# doing for index 1440
# doing for index 1441
# doing for index 1442
# doing for index 1443
# doing for index 1444
# doing for index 1445
# doing for index 1446
# doing for index 1447
# doing for index 1448
# doing for index 1449
# doing for index 1450
# doing for index 1451
# doing for index 1452
# doing for index 1453
# doing for index 1454
# doing for index 1455
# doing for index 1456
# doing for index 1457
# doing for index 1458
# doing for index 1459
# doing for index 1460
# doing for index 1461
# doing for index 1462
# doing for index 1463
# doing for index 1464
# doing for index 1465
# doing for index 1466
# doing for index 1467
# doing for index 1468
# doing for index 1469
# doing for index 1470
# doing for index 1471
# doing for index 1472
# doing for index 1473
# doing for index 1474
# doing for index 1475
# doing for index 1476
# doing for index 1477
# doing for index 1478
# doing for index 1479
# doing for index 1480
# doing for index 1481
# doing for index 1482
# doing for index 1483
# doing for index 1484
# doing for index 1485
# doing for index 1486
# doing for index 1487
# doing for index 1488
# doing for index 1489
# doing for index 1490
# doing for index 1491
# doing for index 1492
# doing for index 1493
# doing for index 1494
# doing for index 1495
# doing for index 1496
# doing for index 1497
# doing for index 1498
# doing for index 1499
# doing for index 1500
# doing for index 1501
# doing for index 1502
# doing for index 1503
# doing for index 1504
# doing for index 1505
# doing for index 1506
# doing for index 1507
# doing for index 1508
# doing for index 1509
# doing for index 1510
# doing for index 1511
# doing for index 1512
# doing for index 1513
# doing for index 1514
# doing for index 1515
# doing for index 1516
# doing for index 1517
# doing for index 1518
# doing for index 1519
# doing for index 1520
# doing for index 1521
# doing for index 1522
# doing for index 1523
# doing for index 1524
# doing for index 1525
# doing for index 1526
# doing for index 1527
# doing for index 1528
# doing for index 1529
# doing for index 1530
# doing for index 1531
# doing for index 1532
# doing for index 1533
# doing for index 1534
# doing for index 1535
# doing for index 1536
# doing for index 1537
# doing for index 1538
# doing for index 1539
# doing for index 1540
# doing for index 1541
# doing for index 1542
# doing for index 1543
# doing for index 1544
# doing for index 1545
# doing for index 1546
# doing for index 1547
# doing for index 1548
# doing for index 1549
# doing for index 1550
# doing for index 1551
# doing for index 1552
# doing for index 1553
# doing for index 1554
# doing for index 1555
# doing for index 1556
# doing for index 1557
# doing for index 1558
# doing for index 1559
# doing for index 1560
# doing for index 1561
# doing for index 1562
# doing for index 1563
# doing for index 1564
# doing for index 1565
# doing for index 1566
# doing for index 1567
# doing for index 1568
# doing for index 1569
# doing for index 1570
# doing for index 1571
# doing for index 1572
# doing for index 1573
# doing for index 1574
# doing for index 1575
# doing for index 1576
# doing for index 1577
# doing for index 1578
# doing for index 1579
# doing for index 1580
# doing for index 1581
# doing for index 1582
# doing for index 1583
# doing for index 1584
# doing for index 1585
# doing for index 1586
# doing for index 1587
# doing for index 1588
# doing for index 1589
# doing for index 1590
# doing for index 1591
# doing for index 1592
# doing for index 1593
# doing for index 1594
# doing for index 1595
# doing for index 1596
# doing for index 1597
# doing for index 1598
# doing for index 1599
# doing for index 1600
# doing for index 1601
# doing for index 1602
# doing for index 1603
# doing for index 1604
# doing for index 1605
# doing for index 1606
# doing for index 1607
# doing for index 1608
# doing for index 1609
# doing for index 1610
# doing for index 1611
# doing for index 1612
# doing for index 1613
# doing for index 1614
# doing for index 1615
# doing for index 1616
# doing for index 1617
# doing for index 1618
# doing for index 1619
# doing for index 1620
# doing for index 1621
# doing for index 1622
# doing for index 1623
# doing for index 1624
# doing for index 1625
# doing for index 1626
# doing for index 1627
# doing for index 1628
# doing for index 1629
# doing for index 1630
# doing for index 1631
# doing for index 1632
# doing for index 1633
# doing for index 1634
# doing for index 1635
# doing for index 1636
# doing for index 1637
# doing for index 1638
# doing for index 1639
# doing for index 1640
# doing for index 1641
# doing for index 1642
# doing for index 1643
# doing for index 1644
# doing for index 1645
# doing for index 1646
# doing for index 1647
# doing for index 1648
# doing for index 1649
# doing for index 1650
# doing for index 1651
# doing for index 1652
# doing for index 1653
# doing for index 1654
# doing for index 1655
# doing for index 1656
# doing for index 1657
# doing for index 1658
# doing for index 1659
# doing for index 1660
# doing for index 1661
# doing for index 1662
# doing for index 1663
# doing for index 1664
# doing for index 1665
# doing for index 1666
# doing for index 1667
# doing for index 1668
# doing for index 1669
# doing for index 1670
# doing for index 1671
# doing for index 1672
# doing for index 1673
# doing for index 1674
# doing for index 1675
# doing for index 1676
# doing for index 1677
# doing for index 1678
# doing for index 1679
# doing for index 1680
# doing for index 1681
# doing for index 1682
# doing for index 1683
# doing for index 1684
# doing for index 1685
# doing for index 1686
# doing for index 1687
# doing for index 1688
# doing for index 1689
# doing for index 1690
# doing for index 1691
# doing for index 1692
# doing for index 1693
# doing for index 1694
# doing for index 1695
# doing for index 1696
# doing for index 1697
# doing for index 1698
# doing for index 1699
# doing for index 1700
# doing for index 1701
# doing for index 1702
# doing for index 1703
# doing for index 1704
# doing for index 1705
# doing for index 1706
# doing for index 1707
# doing for index 1708
# doing for index 1709
# doing for index 1710
# doing for index 1711
# doing for index 1712
# doing for index 1713
# doing for index 1714
# doing for index 1715
# doing for index 1716
# doing for index 1717
# doing for index 1718
# doing for index 1719
# doing for index 1720
# doing for index 1721
# doing for index 1722
# doing for index 1723
# doing for index 1724
# doing for index 1725
# doing for index 1726
# doing for index 1727
# doing for index 1728
# doing for index 1729
# doing for index 1730
# doing for index 1731
# doing for index 1732
# doing for index 1733
# doing for index 1734
# doing for index 1735
# doing for index 1736
# doing for index 1737
# doing for index 1738
# doing for index 1739
# doing for index 1740
# doing for index 1741
# doing for index 1742
# doing for index 1743
# doing for index 1744
# doing for index 1745
# doing for index 1746
# doing for index 1747
# doing for index 1748
# doing for index 1749
# doing for index 1750
# doing for index 1751
# doing for index 1752
# doing for index 1753
# doing for index 1754
# doing for index 1755
# doing for index 1756
# doing for index 1757
# doing for index 1758
# doing for index 1759
# doing for index 1760
# doing for index 1761
# doing for index 1762
# doing for index 1763
# doing for index 1764
# doing for index 1765
# doing for index 1766
# doing for index 1767
# doing for index 1768
# doing for index 1769
# doing for index 1770
# doing for index 1771
# doing for index 1772
# doing for index 1773
# doing for index 1774
# doing for index 1775
# doing for index 1776
# doing for index 1777
# doing for index 1778
# doing for index 1779
# doing for index 1780
# doing for index 1781
# doing for index 1782
# doing for index 1783
# doing for index 1784
# doing for index 1785
# doing for index 1786
# doing for index 1787
# doing for index 1788
# doing for index 1789
# doing for index 1790
# doing for index 1791
# doing for index 1792
# doing for index 1793
# doing for index 1794
# doing for index 1795
# doing for index 1796
# doing for index 1797
# doing for index 1798
# doing for index 1799
# doing for index 1800
# doing for index 1801
# doing for index 1802
# doing for index 1803
# doing for index 1804
# doing for index 1805
# doing for index 1806
# doing for index 1807
# doing for index 1808
# doing for index 1809
# doing for index 1810
# doing for index 1811
# doing for index 1812
# doing for index 1813
# doing for index 1814
# doing for index 1815
# doing for index 1816
# doing for index 1817
# doing for index 1818
# doing for index 1819
# doing for index 1820
# doing for index 1821
# doing for index 1822
# doing for index 1823
# doing for index 1824
# doing for index 1825
# doing for index 1826
# doing for index 1827
# doing for index 1828
# doing for index 1829
# doing for index 1830
# doing for index 1831
# doing for index 1832
# doing for index 1833
# doing for index 1834
# doing for index 1835
# doing for index 1836
# doing for index 1837
# doing for index 1838
# doing for index 1839
# doing for index 1840
# doing for index 1841
# doing for index 1842
# doing for index 1843
# doing for index 1844
# doing for index 1845
# doing for index 1846
# doing for index 1847
# doing for index 1848
# doing for index 1849
# doing for index 1850
# doing for index 1851
# doing for index 1852
# doing for index 1853
# doing for index 1854
# doing for index 1855
# doing for index 1856
# doing for index 1857
# doing for index 1858
# doing for index 1859
# doing for index 1860
# doing for index 1861
# doing for index 1862
# doing for index 1863
# doing for index 1864
# doing for index 1865
# doing for index 1866
# doing for index 1867
# doing for index 1868
# doing for index 1869
# doing for index 1870
# doing for index 1871
# doing for index 1872
# doing for index 1873
# doing for index 1874
# doing for index 1875
# doing for index 1876
# doing for index 1877
# doing for index 1878
# doing for index 1879
# doing for index 1880
# doing for index 1881
# doing for index 1882
# doing for index 1883
# doing for index 1884
# doing for index 1885
# doing for index 1886
# doing for index 1887
# doing for index 1888
# doing for index 1889
# doing for index 1890
# doing for index 1891
# doing for index 1892
# doing for index 1893
# doing for index 1894
# doing for index 1895
# doing for index 1896
# doing for index 1897
# doing for index 1898
# doing for index 1899
# doing for index 1900
# doing for index 1901
# doing for index 1902
# doing for index 1903
# doing for index 1904
# doing for index 1905
# doing for index 1906
# doing for index 1907
# doing for index 1908
# doing for index 1909
# doing for index 1910
# doing for index 1911
# doing for index 1912
# doing for index 1913
# doing for index 1914
# doing for index 1915
# doing for index 1916
# doing for index 1917
# doing for index 1918
# doing for index 1919
# doing for index 1920
# doing for index 1921
# doing for index 1922
# doing for index 1923
# doing for index 1924
# doing for index 1925
# doing for index 1926
# doing for index 1927
# doing for index 1928
# doing for index 1929
# doing for index 1930
# doing for index 1931
# doing for index 1932
# doing for index 1933
# doing for index 1934
# doing for index 1935
# doing for index 1936
# doing for index 1937
# doing for index 1938
# doing for index 1939
# doing for index 1940
# doing for index 1941
# doing for index 1942
# doing for index 1943
# doing for index 1944
# doing for index 1945
# doing for index 1946
# doing for index 1947
# doing for index 1948
# doing for index 1949
# doing for index 1950
# doing for index 1951
# doing for index 1952
# doing for index 1953
# doing for index 1954
# doing for index 1955
# doing for index 1956
# doing for index 1957
# doing for index 1958
# doing for index 1959
# doing for index 1960
# doing for index 1961
# doing for index 1962
# doing for index 1963
# doing for index 1964
# doing for index 1965
# doing for index 1966
# doing for index 1967
# doing for index 1968
# doing for index 1969
# doing for index 1970
# doing for index 1971
# doing for index 1972
# doing for index 1973
# doing for index 1974
# doing for index 1975
# doing for index 1976
# doing for index 1977
# doing for index 1978
# doing for index 1979
# doing for index 1980
# doing for index 1981
# doing for index 1982
# doing for index 1983
# doing for index 1984
# doing for index 1985
# doing for index 1986
# doing for index 1987
# doing for index 1988
# doing for index 1989
# doing for index 1990
# doing for index 1991
# doing for index 1992
# doing for index 1993
# doing for index 1994
# doing for index 1995
# doing for index 1996
# doing for index 1997
# doing for index 1998
# doing for index 1999
# doing for index 2000
# doing for index 2001
# doing for index 2002
# doing for index 2003
# doing for index 2004
# doing for index 2005
# doing for index 2006
# doing for index 2007
# doing for index 2008
# doing for index 2009
# doing for index 2010
# doing for index 2011
# doing for index 2012
# doing for index 2013
# doing for index 2014
# doing for index 2015
# doing for index 2016
# doing for index 2017
# doing for index 2018
# doing for index 2019
# doing for index 2020
# doing for index 2021
# doing for index 2022
# doing for index 2023
# doing for index 2024
# doing for index 2025
# doing for index 2026
# doing for index 2027
# doing for index 2028
# doing for index 2029
# doing for index 2030
# doing for index 2031
# doing for index 2032
# doing for index 2033
# doing for index 2034
# doing for index 2035
# doing for index 2036
# doing for index 2037
# doing for index 2038
# doing for index 2039
# doing for index 2040
# doing for index 2041
# doing for index 2042
# doing for index 2043
# doing for index 2044
# doing for index 2045
# doing for index 2046
# doing for index 2047
# doing for index 2048
# doing for index 2049
# doing for index 2050
# doing for index 2051
# doing for index 2052
# doing for index 2053
# doing for index 2054
# doing for index 2055
# doing for index 2056
# doing for index 2057
# doing for index 2058
# doing for index 2059
# doing for index 2060
# doing for index 2061
# doing for index 2062
# doing for index 2063
# doing for index 2064
# doing for index 2065
# doing for index 2066
# doing for index 2067
# doing for index 2068
# doing for index 2069
# doing for index 2070
# doing for index 2071
# doing for index 2072
# doing for index 2073
# doing for index 2074
# doing for index 2075
# doing for index 2076
# doing for index 2077
# doing for index 2078
# doing for index 2079
# doing for index 2080
# doing for index 2081
# doing for index 2082
# doing for index 2083
# doing for index 2084
# doing for index 2085
# doing for index 2086
# doing for index 2087
# doing for index 2088
# doing for index 2089
# doing for index 2090
# doing for index 2091
# doing for index 2092
# doing for index 2093
# doing for index 2094
# doing for index 2095
# doing for index 2096
# doing for index 2097
# doing for index 2098
# doing for index 2099
# doing for index 2100
# doing for index 2101
# doing for index 2102
# doing for index 2103
# doing for index 2104
# doing for index 2105
# doing for index 2106
# doing for index 2107
# doing for index 2108
# doing for index 2109
# doing for index 2110
# doing for index 2111
# doing for index 2112
# doing for index 2113
# doing for index 2114
# doing for index 2115
# doing for index 2116
# doing for index 2117
# doing for index 2118
# doing for index 2119
# doing for index 2120
# doing for index 2121
# doing for index 2122
# doing for index 2123
# doing for index 2124
# doing for index 2125
# doing for index 2126
# doing for index 2127
# doing for index 2128
# doing for index 2129
# doing for index 2130
# doing for index 2131
# doing for index 2132
# doing for index 2133
# doing for index 2134
# doing for index 2135
# doing for index 2136
# doing for index 2137
# doing for index 2138
# doing for index 2139
# doing for index 2140
# doing for index 2141
# doing for index 2142
# doing for index 2143
# doing for index 2144
# doing for index 2145
# doing for index 2146
# doing for index 2147
# doing for index 2148
# doing for index 2149
# doing for index 2150
# doing for index 2151
# doing for index 2152
# doing for index 2153
# doing for index 2154
# doing for index 2155
# doing for index 2156
# doing for index 2157
# doing for index 2158
# doing for index 2159
# doing for index 2160
# doing for index 2161
# doing for index 2162
# doing for index 2163
# doing for index 2164
# doing for index 2165
# doing for index 2166
# doing for index 2167
# doing for index 2168
# doing for index 2169
# doing for index 2170
# doing for index 2171
# doing for index 2172
# doing for index 2173
# doing for index 2174
# doing for index 2175
# doing for index 2176
# doing for index 2177
# doing for index 2178
# doing for index 2179
# doing for index 2180
# doing for index 2181
# doing for index 2182
# doing for index 2183
# doing for index 2184
# doing for index 2185
# doing for index 2186
# doing for index 2187
# doing for index 2188
# doing for index 2189
# doing for index 2190
# doing for index 2191
# doing for index 2192
# doing for index 2193
# doing for index 2194
# doing for index 2195
# doing for index 2196
# doing for index 2197
# doing for index 2198
# doing for index 2199
# doing for index 2200
# doing for index 2201
# doing for index 2202
# doing for index 2203
# doing for index 2204
# doing for index 2205
# doing for index 2206
# doing for index 2207
# doing for index 2208
# doing for index 2209
# doing for index 2210
# doing for index 2211
# doing for index 2212
# doing for index 2213
# doing for index 2214
# doing for index 2215
# doing for index 2216
# doing for index 2217
# doing for index 2218
# doing for index 2219
# doing for index 2220
# doing for index 2221
# doing for index 2222
# doing for index 2223
# doing for index 2224
# doing for index 2225
# doing for index 2226
# doing for index 2227
# doing for index 2228
# doing for index 2229
# doing for index 2230
# doing for index 2231
# doing for index 2232
# doing for index 2233
# doing for index 2234
# doing for index 2235
# doing for index 2236
# doing for index 2237
# doing for index 2238
# doing for index 2239
# doing for index 2240
# doing for index 2241
# doing for index 2242
# doing for index 2243
# doing for index 2244
# doing for index 2245
# doing for index 2246
# doing for index 2247
# doing for index 2248
# doing for index 2249
# doing for index 2250
# doing for index 2251
# doing for index 2252
# doing for index 2253
# doing for index 2254
# doing for index 2255
# doing for index 2256
# doing for index 2257
# doing for index 2258
# doing for index 2259
# doing for index 2260
# doing for index 2261
# doing for index 2262
# doing for index 2263
# doing for index 2264
# doing for index 2265
# doing for index 2266
# doing for index 2267
# doing for index 2268
# doing for index 2269
# doing for index 2270
# doing for index 2271
# doing for index 2272
# doing for index 2273
# doing for index 2274
# doing for index 2275
# doing for index 2276
# doing for index 2277
# doing for index 2278
# doing for index 2279
# doing for index 2280
# doing for index 2281
# doing for index 2282
# doing for index 2283
# doing for index 2284
# doing for index 2285
# doing for index 2286
# doing for index 2287
# doing for index 2288
# doing for index 2289
# doing for index 2290
# doing for index 2291
# doing for index 2292
# doing for index 2293
# doing for index 2294
# doing for index 2295
# doing for index 2296
# doing for index 2297
# doing for index 2298
# doing for index 2299
# doing for index 2300
# doing for index 2301
# doing for index 2302
# doing for index 2303
# doing for index 2304
# doing for index 2305
# doing for index 2306
# doing for index 2307
# doing for index 2308
# doing for index 2309
# doing for index 2310
# doing for index 2311
# doing for index 2312
# doing for index 2313
# doing for index 2314
# doing for index 2315
# doing for index 2316
# doing for index 2317
# doing for index 2318
# doing for index 2319
# doing for index 2320
# doing for index 2321
# doing for index 2322
# doing for index 2323
# doing for index 2324
# doing for index 2325
# doing for index 2326
# doing for index 2327
# doing for index 2328
# doing for index 2329
# doing for index 2330
# doing for index 2331
# doing for index 2332
# doing for index 2333
# doing for index 2334
# doing for index 2335
# doing for index 2336
# doing for index 2337
# doing for index 2338
# ...
# doing for index 3080
# doing for index 3081
# doing for index 3082
# doing for index 3083
# doing for index 3084
# doing for index 3085
# doing for index 3086
# doing for index 3087
# doing for index 3088
# doing for index 3089
# doing for index 3090
# doing for index 3091
# doing for index 3092
# doing for index 3093
# doing for index 3094
# doing for index 3095
# doing for index 3096
# doing for index 3097
# doing for index 3098
# doing for index 3099
# doing for index 3100
# doing for index 3101
# doing for index 3102
# doing for index 3103
# doing for index 3104
# doing for index 3105
# doing for index 3106
# doing for index 3107
# doing for index 3108
# doing for index 3109
# doing for index 3110
# doing for index 3111
# doing for index 3112
# doing for index 3113
# doing for index 3114
# doing for index 3115
# doing for index 3116
# doing for index 3117
# doing for index 3118
# doing for index 3119
# doing for index 3120
# doing for index 3121
# doing for index 3122
# doing for index 3123
# doing for index 3124
# doing for index 3125
# doing for index 3126
# doing for index 3127
# doing for index 3128
# doing for index 3129
# doing for index 3130
# doing for index 3131
# doing for index 3132
# doing for index 3133
# doing for index 3134
# doing for index 3135
# doing for index 3136
# doing for index 3137
# doing for index 3138
# doing for index 3139
# doing for index 3140
# doing for index 3141
# doing for index 3142
# doing for index 3143
# doing for index 3144
# doing for index 3145
# doing for index 3146
# doing for index 3147
# doing for index 3148
# doing for index 3149
# doing for index 3150
# doing for index 3151
# doing for index 3152
# doing for index 3153
# doing for index 3154
# doing for index 3155
# doing for index 3156
# doing for index 3157
# doing for index 3158
# doing for index 3159
# doing for index 3160
# doing for index 3161
# doing for index 3162
# doing for index 3163
# doing for index 3164
# doing for index 3165
# doing for index 3166
# doing for index 3167
# doing for index 3168
# doing for index 3169
# doing for index 3170
# doing for index 3171
# doing for index 3172
# doing for index 3173
# doing for index 3174
# doing for index 3175
# doing for index 3176
# doing for index 3177
# doing for index 3178
# doing for index 3179
# doing for index 3180
# doing for index 3181
# doing for index 3182
# doing for index 3183
# doing for index 3184
# doing for index 3185
# doing for index 3186
# doing for index 3187
# doing for index 3188
# doing for index 3189
# doing for index 3190
# doing for index 3191
# doing for index 3192
# doing for index 3193
# doing for index 3194
# doing for index 3195
# doing for index 3196
# doing for index 3197
# doing for index 3198
# doing for index 3199
# doing for index 3200
# doing for index 3201
# doing for index 3202
# doing for index 3203
# doing for index 3204
# doing for index 3205
# doing for index 3206
# doing for index 3207
# doing for index 3208
# doing for index 3209
# doing for index 3210
# doing for index 3211
# doing for index 3212
# doing for index 3213
# doing for index 3214
# doing for index 3215
# doing for index 3216
# doing for index 3217
# doing for index 3218
# doing for index 3219
# doing for index 3220
# doing for index 3221
# doing for index 3222
# doing for index 3223
# doing for index 3224
# doing for index 3225
# doing for index 3226
# doing for index 3227
# doing for index 3228
# doing for index 3229
# doing for index 3230
# doing for index 3231
# doing for index 3232
# doing for index 3233
# doing for index 3234
# doing for index 3235
# doing for index 3236
# doing for index 3237
# doing for index 3238
# doing for index 3239
# doing for index 3240
# doing for index 3241
# doing for index 3242
# doing for index 3243
# doing for index 3244
# doing for index 3245
# doing for index 3246
# doing for index 3247
# doing for index 3248
# doing for index 3249
# doing for index 3250
# doing for index 3251
# doing for index 3252
# doing for index 3253
# doing for index 3254
# doing for index 3255
# doing for index 3256
# doing for index 3257
# doing for index 3258
# doing for index 3259
# doing for index 3260
# doing for index 3261
# doing for index 3262
# doing for index 3263
# doing for index 3264
# doing for index 3265
# doing for index 3266
# doing for index 3267
# doing for index 3268
# doing for index 3269
# doing for index 3270
# doing for index 3271
# doing for index 3272
# doing for index 3273
# doing for index 3274
# doing for index 3275
# doing for index 3276
# doing for index 3277
# doing for index 3278
# doing for index 3279
# doing for index 3280
# doing for index 3281
# doing for index 3282
# doing for index 3283
# doing for index 3284
# doing for index 3285
# doing for index 3286
# doing for index 3287
# doing for index 3288
# doing for index 3289
# doing for index 3290
# doing for index 3291
# doing for index 3292
# doing for index 3293
# doing for index 3294
# doing for index 3295
# doing for index 3296
# doing for index 3297
# doing for index 3298
# doing for index 3299
# doing for index 3300
# doing for index 3301
# doing for index 3302
# doing for index 3303
# doing for index 3304
# doing for index 3305
# doing for index 3306
# doing for index 3307
# doing for index 3308
# doing for index 3309
# doing for index 3310
# doing for index 3311
# doing for index 3312
# doing for index 3313
# doing for index 3314
# doing for index 3315
# doing for index 3316
# doing for index 3317
# doing for index 3318
# doing for index 3319
# doing for index 3320
# doing for index 3321
# doing for index 3322
# doing for index 3323
# doing for index 3324
# doing for index 3325
# doing for index 3326
# doing for index 3327
# doing for index 3328
# doing for index 3329
# doing for index 3330
# doing for index 3331
# doing for index 3332
# doing for index 3333
# doing for index 3334
# doing for index 3335
# doing for index 3336
# doing for index 3337
# doing for index 3338
# doing for index 3339
# doing for index 3340
# doing for index 3341
# doing for index 3342
# doing for index 3343
# doing for index 3344
# doing for index 3345
# doing for index 3346
# doing for index 3347
# doing for index 3348
# doing for index 3349
# doing for index 3350
# doing for index 3351
# doing for index 3352
# doing for index 3353
# doing for index 3354
# doing for index 3355
# doing for index 3356
# doing for index 3357
# doing for index 3358
# doing for index 3359
# doing for index 3360
# doing for index 3361
# doing for index 3362
# doing for index 3363
# doing for index 3364
# doing for index 3365
# doing for index 3366
# doing for index 3367
# doing for index 3368
# doing for index 3369
# doing for index 3370
# doing for index 3371
# doing for index 3372
# doing for index 3373
# doing for index 3374
# doing for index 3375
# doing for index 3376
# doing for index 3377
# doing for index 3378
# doing for index 3379
# doing for index 3380
# doing for index 3381
# doing for index 3382
# doing for index 3383
# doing for index 3384
# doing for index 3385
# doing for index 3386
# doing for index 3387
# doing for index 3388
# doing for index 3389
# doing for index 3390
# doing for index 3391
# doing for index 3392
# doing for index 3393
# doing for index 3394
# doing for index 3395
# doing for index 3396
# doing for index 3397
# doing for index 3398
# doing for index 3399
# doing for index 3400
# doing for index 3401
# doing for index 3402
# doing for index 3403
# doing for index 3404
# doing for index 3405
# doing for index 3406
# doing for index 3407
# doing for index 3408
# doing for index 3409
# doing for index 3410
# doing for index 3411
# doing for index 3412
# doing for index 3413
# doing for index 3414
# doing for index 3415
# doing for index 3416
# doing for index 3417
# doing for index 3418
# doing for index 3419
# doing for index 3420
# doing for index 3421
# doing for index 3422
# doing for index 3423
# doing for index 3424
# doing for index 3425
# doing for index 3426
# doing for index 3427
# doing for index 3428
# doing for index 3429
# doing for index 3430
# doing for index 3431
# doing for index 3432
# doing for index 3433
# doing for index 3434
# doing for index 3435
# doing for index 3436
# doing for index 3437
# doing for index 3438
# doing for index 3439
# doing for index 3440
# doing for index 3441
# doing for index 3442
# doing for index 3443
# doing for index 3444
# doing for index 3445
# doing for index 3446
# doing for index 3447
# doing for index 3448
# doing for index 3449
# doing for index 3450
# doing for index 3451
# doing for index 3452
# doing for index 3453
# doing for index 3454
# doing for index 3455
# doing for index 3456
# doing for index 3457
# doing for index 3458
# doing for index 3459
# doing for index 3460
# doing for index 3461
# doing for index 3462
# doing for index 3463
# doing for index 3464
# doing for index 3465
# doing for index 3466
# doing for index 3467
# doing for index 3468
# doing for index 3469
# doing for index 3470
# doing for index 3471
# doing for index 3472
# doing for index 3473
# doing for index 3474
# doing for index 3475
# doing for index 3476
# doing for index 3477
# doing for index 3478
# doing for index 3479
# doing for index 3480
# doing for index 3481
# doing for index 3482
# doing for index 3483
# doing for index 3484
# doing for index 3485
# doing for index 3486
# doing for index 3487
# doing for index 3488
# doing for index 3489
# doing for index 3490
# doing for index 3491
# doing for index 3492
# doing for index 3493
# doing for index 3494
# doing for index 3495
# doing for index 3496
# doing for index 3497
# doing for index 3498
# doing for index 3499
# doing for index 3500
# doing for index 3501
# doing for index 3502
# doing for index 3503
# doing for index 3504
# doing for index 3505
# doing for index 3506
# doing for index 3507
# doing for index 3508
# doing for index 3509
# doing for index 3510
# doing for index 3511
# doing for index 3512
# doing for index 3513
# doing for index 3514
# doing for index 3515
# doing for index 3516
# doing for index 3517
# doing for index 3518
# doing for index 3519
# doing for index 3520
# doing for index 3521
# doing for index 3522
# doing for index 3523
# doing for index 3524
# doing for index 3525
# doing for index 3526
# doing for index 3527
# doing for index 3528
# doing for index 3529
# doing for index 3530
# doing for index 3531
# doing for index 3532
# doing for index 3533
# doing for index 3534
# doing for index 3535
# doing for index 3536
# doing for index 3537
# doing for index 3538
# doing for index 3539
# doing for index 3540
# doing for index 3541
# doing for index 3542
# doing for index 3543
# doing for index 3544
# doing for index 3545
# doing for index 3546
# doing for index 3547
# doing for index 3548
# doing for index 3549
# doing for index 3550
# doing for index 3551
# doing for index 3552
# doing for index 3553
# doing for index 3554
# doing for index 3555
# doing for index 3556
# doing for index 3557
# doing for index 3558
# doing for index 3559
# doing for index 3560
# doing for index 3561
# doing for index 3562
# doing for index 3563
# doing for index 3564
# doing for index 3565
# doing for index 3566
# doing for index 3567
# doing for index 3568
# doing for index 3569
# doing for index 3570
# doing for index 3571
# doing for index 3572
# doing for index 3573
# doing for index 3574
# doing for index 3575
# doing for index 3576
# doing for index 3577
# doing for index 3578
# doing for index 3579
# doing for index 3580
# doing for index 3581
# doing for index 3582
# doing for index 3583
# doing for index 3584
# doing for index 3585
# doing for index 3586
# doing for index 3587
# doing for index 3588
# doing for index 3589
# doing for index 3590
# doing for index 3591
# doing for index 3592
# doing for index 3593
# doing for index 3594
# doing for index 3595
# doing for index 3596
# doing for index 3597
# doing for index 3598
# doing for index 3599
# doing for index 3600
# doing for index 3601
# doing for index 3602
# doing for index 3603
# doing for index 3604
# doing for index 3605
# doing for index 3606
# doing for index 3607
# doing for index 3608
# doing for index 3609
# doing for index 3610
# doing for index 3611
# doing for index 3612
# doing for index 3613
# doing for index 3614
# doing for index 3615
# doing for index 3616
# doing for index 3617
# doing for index 3618
# doing for index 3619
# doing for index 3620
# doing for index 3621
# doing for index 3622
# doing for index 3623
# doing for index 3624
# doing for index 3625
# doing for index 3626
# doing for index 3627
# doing for index 3628
# doing for index 3629
# doing for index 3630
# doing for index 3631
# doing for index 3632
# doing for index 3633
# doing for index 3634
# doing for index 3635
# doing for index 3636
# doing for index 3637
# doing for index 3638
# doing for index 3639
# doing for index 3640
# doing for index 3641
# doing for index 3642
# doing for index 3643
# doing for index 3644
# doing for index 3645
# doing for index 3646
# doing for index 3647
# doing for index 3648
# doing for index 3649
# doing for index 3650
# doing for index 3651
# doing for index 3652
# doing for index 3653
# doing for index 3654
# doing for index 3655
# doing for index 3656
# doing for index 3657
# doing for index 3658
# doing for index 3659
# doing for index 3660
# doing for index 3661
# doing for index 3662
# doing for index 3663
# doing for index 3664
# doing for index 3665
# doing for index 3666
# doing for index 3667
# doing for index 3668
# doing for index 3669
# doing for index 3670
# doing for index 3671
# doing for index 3672
# doing for index 3673
# doing for index 3674
# doing for index 3675
# doing for index 3676
# doing for index 3677
# doing for index 3678
# doing for index 3679
# doing for index 3680
# doing for index 3681
# doing for index 3682
# doing for index 3683
# doing for index 3684
# doing for index 3685
# doing for index 3686
# doing for index 3687
# doing for index 3688
# doing for index 3689
# doing for index 3690
# doing for index 3691
# doing for index 3692
# doing for index 3693
# doing for index 3694
# doing for index 3695
# doing for index 3696
# doing for index 3697
# doing for index 3698
# doing for index 3699
# doing for index 3700
# doing for index 3701
# doing for index 3702
# doing for index 3703
# doing for index 3704
# doing for index 3705
# doing for index 3706
# doing for index 3707
# doing for index 3708
# doing for index 3709
# doing for index 3710
# doing for index 3711
# doing for index 3712
# doing for index 3713
# doing for index 3714
# doing for index 3715
# doing for index 3716
# doing for index 3717
# doing for index 3718
# doing for index 3719
# doing for index 3720
# doing for index 3721
# doing for index 3722
# doing for index 3723
# doing for index 3724
# doing for index 3725
# doing for index 3726
# doing for index 3727
# doing for index 3728
# doing for index 3729
# doing for index 3730
# doing for index 3731
# doing for index 3732
# doing for index 3733
# doing for index 3734
# doing for index 3735
# doing for index 3736
# doing for index 3737
# doing for index 3738
# doing for index 3739
# doing for index 3740
# doing for index 3741
# doing for index 3742
# doing for index 3743
# doing for index 3744
# doing for index 3745
# doing for index 3746
# doing for index 3747
# doing for index 3748
# doing for index 3749
# doing for index 3750
# doing for index 3751
# doing for index 3752
# doing for index 3753
# doing for index 3754
# doing for index 3755
# doing for index 3756
# doing for index 3757
# doing for index 3758
# doing for index 3759
# doing for index 3760
# doing for index 3761
# doing for index 3762
# doing for index 3763
# doing for index 3764
# doing for index 3765
# doing for index 3766
# doing for index 3767
# doing for index 3768
# doing for index 3769
# doing for index 3770
# doing for index 3771
# doing for index 3772
# doing for index 3773
# doing for index 3774
# doing for index 3775
# doing for index 3776
# doing for index 3777
# doing for index 3778
# doing for index 3779
# doing for index 3780
# doing for index 3781
# doing for index 3782
# doing for index 3783
# doing for index 3784
# doing for index 3785
# doing for index 3786
# doing for index 3787
# doing for index 3788
# doing for index 3789
# doing for index 3790
# doing for index 3791
# doing for index 3792
# doing for index 3793
# doing for index 3794
# doing for index 3795
# doing for index 3796
# doing for index 3797
# doing for index 3798
# doing for index 3799
# doing for index 3800
# doing for index 3801
# doing for index 3802
# doing for index 3803
# doing for index 3804
# doing for index 3805
# doing for index 3806
# doing for index 3807
# doing for index 3808
# doing for index 3809
# doing for index 3810
# doing for index 3811
# doing for index 3812
# doing for index 3813
# doing for index 3814
# doing for index 3815
# doing for index 3816
# doing for index 3817
# doing for index 3818
# doing for index 3819
# doing for index 3820
# doing for index 3821
# doing for index 3822
# doing for index 3823
# doing for index 3824
# doing for index 3825
# doing for index 3826
# doing for index 3827
# doing for index 3828
# doing for index 3829
# doing for index 3830
# doing for index 3831
# doing for index 3832
# doing for index 3833
# doing for index 3834
# doing for index 3835
# doing for index 3836
# doing for index 3837
# doing for index 3838
# doing for index 3839
# doing for index 3840

# %%
dic2 = get_balloon_dicts('test')
# Out:
# doing for index 1
# doing for index 2
# doing for index 3
# doing for index 4
# doing for index 5
# doing for index 6
# doing for index 7
# doing for index 8
# doing for index 9
# doing for index 10
# doing for index 11
# doing for index 12
# doing for index 13
# doing for index 14
# doing for index 15
# doing for index 16
# doing for index 17
# doing for index 18
# doing for index 19
# doing for index 20
# doing for index 21
# doing for index 22
# doing for index 23
# doing for index 24
# doing for index 25
# doing for index 26
# doing for index 27
# doing for index 28
# doing for index 29
# doing for index 30
# doing for index 31
# doing for index 32
# doing for index 33
# doing for index 34
# doing for index 35
# doing for index 36
# doing for index 37
# doing for index 38
# doing for index 39
# doing for index 40
# doing for index 41
# doing for index 42
# doing for index 43
# doing for index 44
# doing for index 45
# doing for index 46
# doing for index 47
# doing for index 48
# doing for index 49
# doing for index 50
# doing for index 51
# doing for index 52
# doing for index 53
# doing for index 54
# doing for index 55
# doing for index 56
# doing for index 57
# doing for index 58
# doing for index 59
# doing for index 60
# doing for index 61
# doing for index 62
# doing for index 63
# doing for index 64
# doing for index 65
# doing for index 66
# doing for index 67
# doing for index 68
# doing for index 69
# doing for index 70
# doing for index 71
# doing for index 72
# doing for index 73
# doing for index 74
# doing for index 75
# doing for index 76
# doing for index 77
# doing for index 78
# doing for index 79
# doing for index 80
# doing for index 81
# doing for index 82
# doing for index 83
# doing for index 84
# doing for index 85
# doing for index 86
# doing for index 87
# doing for index 88
# doing for index 89
# doing for index 90
# doing for index 91
# doing for index 92
# doing for index 93
# doing for index 94
# doing for index 95
# doing for index 96
# doing for index 97
# doing for index 98
# doing for index 99
# doing for index 100
# doing for index 101
# doing for index 102
# doing for index 103
# doing for index 104
# doing for index 105
# doing for index 106
# doing for index 107
# doing for index 108
# doing for index 109
# doing for index 110
# doing for index 111
# doing for index 112
# doing for index 113
# doing for index 114
# doing for index 115
# doing for index 116
# doing for index 117
# doing for index 118
# doing for index 119
# doing for index 120
# doing for index 121
# doing for index 122
# doing for index 123
# doing for index 124
# doing for index 125
# doing for index 126
# doing for index 127
# doing for index 128
# doing for index 129
# doing for index 130
# doing for index 131
# doing for index 132
# doing for index 133
# doing for index 134
# doing for index 135
# doing for index 136
# doing for index 137
# doing for index 138
# doing for index 139
# doing for index 140
# doing for index 141
# doing for index 142
# doing for index 143
# doing for index 144
# doing for index 145
# doing for index 146
# doing for index 147
# doing for index 148
# doing for index 149
# doing for index 150
# doing for index 151
# doing for index 152
# doing for index 153
# doing for index 154
# doing for index 155
# doing for index 156
# doing for index 157
# doing for index 158
# doing for index 159
# doing for index 160
# doing for index 161
# doing for index 162
# doing for index 163
# doing for index 164
# doing for index 165
# doing for index 166
# doing for index 167
# doing for index 168
# doing for index 169
# doing for index 170
# doing for index 171
# doing for index 172
# doing for index 173
# doing for index 174
# doing for index 175
# doing for index 176
# doing for index 177
# doing for index 178
# doing for index 179
# doing for index 180
# doing for index 181
# doing for index 182
# doing for index 183
# doing for index 184
# doing for index 185
# doing for index 186
# doing for index 187
# doing for index 188
# doing for index 189
# doing for index 190
# doing for index 191
# doing for index 192
# doing for index 193
# doing for index 194
# doing for index 195
# doing for index 196
# doing for index 197
# doing for index 198
# doing for index 199
# doing for index 200
# doing for index 201
# doing for index 202
# doing for index 203
# doing for index 204
# doing for index 205
# doing for index 206
# doing for index 207
# doing for index 208
# doing for index 209
# doing for index 210
# doing for index 211
# doing for index 212
# doing for index 213
# doing for index 214
# doing for index 215
# doing for index 216
# doing for index 217
# doing for index 218
# doing for index 219
# doing for index 220
# doing for index 221
# doing for index 222
# doing for index 223
# doing for index 224
# doing for index 225
# doing for index 226
# doing for index 227
# doing for index 228
# doing for index 229
# doing for index 230
# doing for index 231
# doing for index 232
# doing for index 233
# doing for index 234
# doing for index 235
# doing for index 236
# doing for index 237
# doing for index 238
# doing for index 239
# doing for index 240
# doing for index 241
# doing for index 242
# doing for index 243
# doing for index 244
# doing for index 245
# doing for index 246
# doing for index 247
# doing for index 248
# doing for index 249
# doing for index 250
# doing for index 251
# doing for index 252
# doing for index 253
# doing for index 254
# doing for index 255
# doing for index 256
# doing for index 257
# doing for index 258
# doing for index 259
# doing for index 260
# doing for index 261
# doing for index 262
# doing for index 263
# doing for index 264
# doing for index 265
# doing for index 266
# doing for index 267
# doing for index 268
# doing for index 269
# doing for index 270
# doing for index 271
# doing for index 272
# doing for index 273
# doing for index 274
# doing for index 275
# doing for index 276
# doing for index 277
# doing for index 278
# doing for index 279
# doing for index 280
# doing for index 281
# doing for index 282
# doing for index 283
# doing for index 284
# doing for index 285
# doing for index 286
# doing for index 287
# doing for index 288
# doing for index 289
# doing for index 290
# doing for index 291
# doing for index 292
# doing for index 293
# doing for index 294
# doing for index 295
# doing for index 296
# doing for index 297
# doing for index 298
# doing for index 299
# doing for index 300
# doing for index 301
# doing for index 302
# doing for index 303
# doing for index 304
# doing for index 305
# doing for index 306
# doing for index 307
# doing for index 308
# doing for index 309
# doing for index 310
# doing for index 311
# doing for index 312
# doing for index 313
# doing for index 314
# doing for index 315
# doing for index 316
# doing for index 317
# doing for index 318
# doing for index 319
# doing for index 320
# doing for index 321
# doing for index 322
# doing for index 323
# doing for index 324
# doing for index 325
# doing for index 326
# doing for index 327
# doing for index 328
# doing for index 329
# doing for index 330
# doing for index 331
# doing for index 332
# doing for index 333
# doing for index 334
# doing for index 335
# doing for index 336
# doing for index 337
# doing for index 338
# doing for index 339
# doing for index 340
# doing for index 341
# doing for index 342
# doing for index 343
# doing for index 344
# doing for index 345
# doing for index 346
# doing for index 347
# doing for index 348
# doing for index 349
# doing for index 350
# doing for index 351
# doing for index 352
# doing for index 353
# doing for index 354
# doing for index 355
# doing for index 356
# doing for index 357
# doing for index 358
# doing for index 359
# doing for index 360
# doing for index 361
# doing for index 362
# doing for index 363
# doing for index 364
# doing for index 365
# doing for index 366
# doing for index 367
# doing for index 368
# doing for index 369
# doing for index 370
# doing for index 371
# doing for index 372
# doing for index 373
# doing for index 374
# doing for index 375
# doing for index 376
# doing for index 377
# doing for index 378
# doing for index 379
# doing for index 380
# doing for index 381
# doing for index 382
# doing for index 383
# doing for index 384
# doing for index 385
# doing for index 386
# doing for index 387
# doing for index 388
# doing for index 389
# doing for index 390
# doing for index 391
# doing for index 392
# doing for index 393
# doing for index 394
# doing for index 395
# doing for index 396
# doing for index 397
# doing for index 398
# doing for index 399
# doing for index 400
# doing for index 401
# doing for index 402
# doing for index 403
# doing for index 404
# doing for index 405
# doing for index 406
# doing for index 407
# doing for index 408
# doing for index 409
# doing for index 410
# doing for index 411
# doing for index 412
# doing for index 413
# doing for index 414
# doing for index 415
# doing for index 416
# doing for index 417
# doing for index 418
# doing for index 419
# doing for index 420
# doing for index 421
# doing for index 422
# doing for index 423
# doing for index 424
# doing for index 425
# doing for index 426
# doing for index 427
# doing for index 428
# doing for index 429
# doing for index 430
# doing for index 431
# doing for index 432
# doing for index 433
# doing for index 434
# doing for index 435
# doing for index 436
# doing for index 437
# doing for index 438
# doing for index 439
# doing for index 440
# doing for index 441
# doing for index 442
# doing for index 443
# doing for index 444
# doing for index 445
# doing for index 446
# doing for index 447
# doing for index 448
# doing for index 449
# doing for index 450
# doing for index 451
# doing for index 452
# doing for index 453
# doing for index 454
# doing for index 455
# doing for index 456
# doing for index 457
# doing for index 458
# doing for index 459
# doing for index 460
# doing for index 461
# doing for index 462
# doing for index 463
# doing for index 464
# doing for index 465
# doing for index 466
# doing for index 467
# doing for index 468
# doing for index 469
# doing for index 470
# doing for index 471
# doing for index 472
# doing for index 473
# doing for index 474
# doing for index 475
# doing for index 476
# doing for index 477
# doing for index 478
# doing for index 479
# doing for index 480
# doing for index 481
# doing for index 482
# doing for index 483
# doing for index 484
# doing for index 485
# doing for index 486
# doing for index 487
# doing for index 488
# doing for index 489
# doing for index 490
# doing for index 491
# doing for index 492
# doing for index 493
# doing for index 494
# doing for index 495
# doing for index 496
# doing for index 497
# doing for index 498
# doing for index 499
# doing for index 500
# doing for index 501
# doing for index 502
# doing for index 503
# doing for index 504
# doing for index 505
# doing for index 506
# doing for index 507
# doing for index 508
# doing for index 509
# doing for index 510
# doing for index 511
# doing for index 512
# doing for index 513
# doing for index 514
# doing for index 515
# doing for index 516
# doing for index 517
# doing for index 518
# doing for index 519
# doing for index 520
# doing for index 521
# doing for index 522
# doing for index 523
# doing for index 524
# doing for index 525
# doing for index 526
# doing for index 527
# doing for index 528
# doing for index 529
# doing for index 530
# doing for index 531
# doing for index 532
# doing for index 533
# doing for index 534
# doing for index 535
# doing for index 536
# doing for index 537
# doing for index 538
# doing for index 539
# doing for index 540
# doing for index 541
# doing for index 542
# doing for index 543
# doing for index 544
# doing for index 545
# doing for index 546
# doing for index 547
# doing for index 548
# doing for index 549
# doing for index 550
# doing for index 551
# doing for index 552
# doing for index 553
# doing for index 554
# doing for index 555
# doing for index 556
# doing for index 557
# doing for index 558
# doing for index 559
# doing for index 560
# doing for index 561
# doing for index 562
# doing for index 563
# doing for index 564
# doing for index 565
# doing for index 566
# doing for index 567
# doing for index 568
# doing for index 569
# doing for index 570
# doing for index 571
# doing for index 572
# doing for index 573
# doing for index 574
# doing for index 575
# doing for index 576
# doing for index 577
# doing for index 578
# doing for index 579
# doing for index 580
# doing for index 581
# doing for index 582
# doing for index 583
# doing for index 584
# doing for index 585
# doing for index 586
# doing for index 587
# doing for index 588
# doing for index 589
# doing for index 590
# doing for index 591
# doing for index 592
# doing for index 593
# doing for index 594
# doing for index 595
# doing for index 596
# doing for index 597
# doing for index 598
# doing for index 599
# doing for index 600
# doing for index 601
# doing for index 602
# doing for index 603
# doing for index 604
# doing for index 605
# doing for index 606
# doing for index 607
# doing for index 608
# doing for index 609
# doing for index 610
# doing for index 611
# doing for index 612
# doing for index 613
# doing for index 614
# doing for index 615
# doing for index 616
# doing for index 617
# doing for index 618
# doing for index 619
# doing for index 620
# doing for index 621
# doing for index 622
# doing for index 623
# doing for index 624
# doing for index 625
# doing for index 626
# doing for index 627
# doing for index 628
# doing for index 629
# doing for index 630
# doing for index 631
# doing for index 632
# doing for index 633
# doing for index 634
# doing for index 635
# doing for index 636
# doing for index 637
# doing for index 638
# doing for index 639
# doing for index 640
# doing for index 641
# doing for index 642
# doing for index 643
# doing for index 644
# doing for index 645
# doing for index 646
# doing for index 647
# doing for index 648
# doing for index 649
# doing for index 650
# doing for index 651
# doing for index 652
# doing for index 653
# doing for index 654
# doing for index 655
# doing for index 656
# doing for index 657
# doing for index 658
# doing for index 659
# doing for index 660
# doing for index 661
# doing for index 662
# doing for index 663
# doing for index 664
# doing for index 665
# doing for index 666
# doing for index 667
# doing for index 668
# doing for index 669
# doing for index 670
# doing for index 671
# doing for index 672
# doing for index 673
# doing for index 674
# doing for index 675
# doing for index 676
# doing for index 677
# doing for index 678
# doing for index 679
# doing for index 680
# doing for index 681
# doing for index 682
# doing for index 683
# doing for index 684
# doing for index 685
# doing for index 686
# doing for index 687
# doing for index 688
# doing for index 689
# doing for index 690
# doing for index 691
# doing for index 692
# doing for index 693
# doing for index 694
# doing for index 695
# doing for index 696
# doing for index 697
# doing for index 698
# doing for index 699
# doing for index 700
# doing for index 701
# doing for index 702
# doing for index 703
# doing for index 704
# doing for index 705
# doing for index 706
# doing for index 707
# doing for index 708
# doing for index 709
# doing for index 710
# doing for index 711
# doing for index 712
# doing for index 713
# doing for index 714
# doing for index 715
# doing for index 716
# doing for index 717
# doing for index 718
# doing for index 719
# doing for index 720
# doing for index 721
# doing for index 722
# doing for index 723
# doing for index 724
# doing for index 725
# doing for index 726
# doing for index 727
# doing for index 728
# doing for index 729
# doing for index 730
# doing for index 731
# doing for index 732
# doing for index 733
# doing for index 734
# doing for index 735
# doing for index 736
# doing for index 737
# doing for index 738
# doing for index 739
# doing for index 740
# doing for index 741
# doing for index 742
# doing for index 743
# doing for index 744
# doing for index 745
# doing for index 746
# doing for index 747
# doing for index 748
# doing for index 749
# doing for index 750
# doing for index 751
# doing for index 752
# doing for index 753
# doing for index 754
# doing for index 755
# doing for index 756
# doing for index 757
# doing for index 758
# doing for index 759
# doing for index 760
# doing for index 761
# doing for index 762
# doing for index 763
# doing for index 764
# doing for index 765
# doing for index 766
# doing for index 767
# doing for index 768
# doing for index 769
# doing for index 770
# doing for index 771
# doing for index 772
# doing for index 773
# doing for index 774
# doing for index 775
# doing for index 776
# doing for index 777
# doing for index 778
# doing for index 779
# doing for index 780
# doing for index 781
# doing for index 782
# doing for index 783
# doing for index 784
# doing for index 785
# doing for index 786
# doing for index 787
# doing for index 788
# doing for index 789
# doing for index 790
# doing for index 791
# doing for index 792
# doing for index 793
# doing for index 794
# doing for index 795
# doing for index 796
# doing for index 797
# doing for index 798
# doing for index 799
# doing for index 800
# doing for index 801
# doing for index 802
# doing for index 803
# doing for index 804
# doing for index 805
# doing for index 806
# doing for index 807
# doing for index 808
# doing for index 809
# doing for index 810
# doing for index 811
# doing for index 812
# doing for index 813
# doing for index 814
# doing for index 815
# doing for index 816
# doing for index 817
# doing for index 818
# doing for index 819
# doing for index 820
# doing for index 821
# doing for index 822
# doing for index 823
# doing for index 824
# doing for index 825
# doing for index 826
# doing for index 827
# doing for index 828
# doing for index 829
# doing for index 830
# doing for index 831
# doing for index 832
# doing for index 833
# doing for index 834
# doing for index 835
# doing for index 836
# doing for index 837
# doing for index 838
# doing for index 839
# doing for index 840
# doing for index 841
# doing for index 842
# doing for index 843
# doing for index 844
# doing for index 845
# doing for index 846
# doing for index 847
# doing for index 848
# doing for index 849
# doing for index 850
# doing for index 851
# doing for index 852
# doing for index 853
# doing for index 854
# doing for index 855
# doing for index 856
# doing for index 857
# doing for index 858
# doing for index 859
# doing for index 860
# doing for index 861
# doing for index 862
# doing for index 863
# doing for index 864
# doing for index 865
# doing for index 866
# doing for index 867
# doing for index 868
# doing for index 869
# doing for index 870
# doing for index 871
# doing for index 872
# doing for index 873
# doing for index 874
# doing for index 875
# doing for index 876
# doing for index 877
# doing for index 878
# doing for index 879
# doing for index 880
# doing for index 881
# doing for index 882
# doing for index 883
# doing for index 884
# doing for index 885
# doing for index 886
# doing for index 887
# doing for index 888
# doing for index 889
# doing for index 890
# doing for index 891
# doing for index 892
# doing for index 893
# doing for index 894
# doing for index 895
# doing for index 896
# doing for index 897
# doing for index 898
# doing for index 899
# doing for index 900
# doing for index 901
# doing for index 902
# doing for index 903
# doing for index 904
# doing for index 905
# doing for index 906
# doing for index 907
# doing for index 908
# doing for index 909
# doing for index 910
# doing for index 911
# doing for index 912
# doing for index 913
# doing for index 914
# doing for index 915
# doing for index 916
# doing for index 917
# doing for index 918
# doing for index 919
# doing for index 920
# doing for index 921
# doing for index 922
# doing for index 923
# doing for index 924
# doing for index 925
# doing for index 926
# doing for index 927
# doing for index 928
# doing for index 929
# doing for index 930
# doing for index 931
# doing for index 932
# doing for index 933
# doing for index 934
# doing for index 935
# doing for index 936
# doing for index 937
# doing for index 938
# doing for index 939
# doing for index 940
# doing for index 941
# doing for index 942
# doing for index 943
# doing for index 944
# doing for index 945
# doing for index 946
# doing for index 947
# doing for index 948
# doing for index 949
# doing for index 950
# doing for index 951
# doing for index 952
# doing for index 953
# doing for index 954
# doing for index 955
# doing for index 956
# doing for index 957
# doing for index 958
# doing for index 959
# doing for index 960

# %%
# Radius of circle
radius = 20
  
# Blue color in BGR
color = (255, 0, 0)
  
# Line thickness of 2 px
thickness = 2

# %%
d= dic2[0]
img = cv2.imread(d['file_name'])
for objs in d["annotations"]:
  seg = objs["segmentation"]
  i = 0
  j = 1
  print(len(seg))
  while i<len(seg):
    img = cv2.circle(img, (seg[i],seg[j]), radius, color, thickness)
    i = i+2
    j = j+2
# Out:
# 1
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-59-3f0cf2ddf4bc> in <module>()
#       7   print(len(seg))
#       8   while i<len(seg):
# ----> 9     img = cv2.circle(img, (seg[i],seg[j]), radius, color, thickness)
#      10     i = i+2
#      11     j = j+2
#
# IndexError: list index out of range
